# %%
import pandas as pd
import matplotlib.pyplot as plot

data={"Name":["Nathan","Femi","Lydia","Paul","Cynthia"],
      "Heights":[6.2,5.4,5.6,2.1,5.8]
     }
dataframe = pd.DataFrame(data=data);

dataframe.plot.bar(x="Name",y="Heights")
plot.show(block=True)
